# %% [markdown]
# # 02 — IR Visualization
#
# This notebook loads the IR produced by Notebook 01 and displays it in a readable format.
#
# Pipeline:
# NL → IR → Mapped IR → Code → Execution → Analysis
#
# This notebook:
# - Loads the IR JSON file
# - Pretty-prints the structure
# - Optionally visualizes steps in a simple table

# %%
from pathlib import Path
import json
from pprint import pprint

# %% [markdown]
# ## 1. Load IR from Disk
#
# We load the IR generated by Notebook 01.

# %%
ir_path = Path("../sample-data/ir_examples/todomvc_ir.json")

with open(ir_path, "r") as f:
    ir = json.load(f)

ir
# Out:
# {'test_name': 'todomvc_add_and_complete_items', 'description': 'Add “buy milk”, add “get gas in Susie’s car”, then complete “buy milk”, and complete “get gas in Susie’s car”.\n', 'steps': [{'action': 'input', 'target': 'new_todo_input', 'value': 'buy milk'}, {'action': 'press', 'target': 'new_todo_input', 'key': 'Enter'}, {'action': 'input', 'target': 'new_todo_input', 'value': 'get gas in Susie’s car'}, {'action': 'press', 'target': 'new_todo_input', 'key': 'Enter'}, {'action': 'click', 'target': 'todo_item_1_checkbox'}, {'action': 'click', 'target': 'todo_item_2_checkbox'}], 'metadata': {'priority': 'high'}}

# %% [markdown]
# ## 2. Pretty-Print IR
#
# This gives a clean, readable view of the IR structure.

# %%
pprint(ir)
# Out:
# {'description': 'Add “buy milk”, add “get gas in Susie’s car”, then complete '
#                 '“buy milk”, and complete “get gas in Susie’s car”.\n',
#  'metadata': {'priority': 'high'},
#  'steps': [{'action': 'input', 'target': 'new_todo_input', 'value': 'buy milk'},
#            {'action': 'press', 'key': 'Enter', 'target': 'new_todo_input'},
#            {'action': 'input',
#             'target': 'new_todo_input',
#             'value': 'get gas in Susie’s car'},
#            {'action': 'press', 'key': 'Enter', 'target': 'new_todo_input'},
#            {'action': 'click', 'target': 'todo_item_1_checkbox'},
#            {'action': 'click', 'target': 'todo_item_2_checkbox'}],
#  'test_name': 'todomvc_add_and_complete_items'}
